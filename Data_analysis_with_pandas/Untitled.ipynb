# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'supermarket-semi-col.txt',
#  'supermarket.csv',
#  'supermarket.json',
#  'supermarket.txt',
#  'supermarket.xlsx',
#  'Untitled.ipynb']

# %%
import pandas

# %%
df = pandas.read_json("supermarket.json")
df.set_index("ID")
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
df2 = pandas.read_csv("supermarket.csv")
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
data_excel = pandas.read_excel("supermarket.xlsx",sheet_name=0)
data_excel
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
data_txt = pandas.read_csv("supermarket.txt",header=None)
data_txt.columns = ["ID","Address","City", "State","Country", "Name" ,"No. of Employees",] 
data_txt.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     No. of Employees
# ID
# 1                  8
# 2                 15
# 3                 25
# 4                 10
# 5                 12
# 6                 20

# %%
data_sm = pandas.read_csv("supermarket-semi-col.txt",sep=';')
data_sm
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
data_excel
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
data_excel.set_index("ID")
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12
# 6                    20

# %%
#converting the data into list and then showing
list(data_excel.loc[:,"Country"])
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
#Showing limited rows and columns
data_excel.iloc[0:3,1:4]
# Out:
#           Address           City             State
# 0    3666 21st St  San Francisco          CA 94114
# 1  735 Dolores St  San Francisco          CA 94119
# 2     332 Hill St  San Francisco  California 94114

# %%
df7=data_excel

# %%
#Adding a column
df7["Continent"]=df7.shape[0]*["North America"]
df7=df7.set_index("ID")

# %%
#transpose of the data
df7_t=df7.T
df7_t
# Out:
# ID                               1               2                 3  \
# Address               3666 21st St  735 Dolores St       332 Hill St
# City                 San Francisco   San Francisco     San Francisco
# State                     CA 94114        CA 94119  California 94114
# Country                        USA             USA               USA
# Supermarket Name           Madeira     Bready Shop       Super River
# Number of Employees              8              15                25
# Continent            North America   North America     North America
#
# ID                               4                5                6
# Address               3995 23rd St  1056 Sanchez St  551 Alvarado St
# City                 San Francisco    San Francisco    San Francisco
# State                     CA 94114       California         CA 94114
# Country                        USA              USA              USA
# Supermarket Name        Ben's Shop          Sanchez       Richvalley
# ...

# %%
df7
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees      Continent              7
# ID
# 1                     8  North America     my address
# 2                    15  North America        my city
# 3                    25  North America       my state
# 4                    10  North America            USA
# 5                    12  North America             54
# 6                    20  North America  North America

# %%
#adding a new row to the transpose data
df7_t["7"]= ["my address","my city", "my state", "USA", "my shop" , "54", "North America" ]
df7_t
# Out:
# ID                               1               2                 3  \
# Address               3666 21st St  735 Dolores St       332 Hill St
# City                 San Francisco   San Francisco     San Francisco
# State                     CA 94114        CA 94119  California 94114
# Country                        USA             USA               USA
# Supermarket Name           Madeira     Bready Shop       Super River
# Number of Employees              8              15                25
# Continent            North America   North America     North America
#
# ID                               4                5                6  \
# Address               3995 23rd St  1056 Sanchez St  551 Alvarado St
# City                 San Francisco    San Francisco    San Francisco
# State                     CA 94114       California         CA 94114
# Country                        USA              USA              USA
# ...

# %%
#Deleting a column
#df7=df7.drop(columns="7")

# %%
# Out:
# ['ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocodeFarm',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
#installing a package in jupyter notebook
#!pip install geopy
#import geopy
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/53/fc/3d1b47e8e82ea12c25203929efb1b964918a77067a874b2c7631e2ec35ec/geopy-1.21.0-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/8b/62/26ec95a98ba64299163199e95ad1b0e34ad3f4e176e221c40245f211e425/geographiclib-1.50-py3-none-any.whl
# ...
# You are using pip version 9.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()

# %%
n=nom.geocode("3666 21st St,San Francisco,CA 94114")
# Out:
# Location(3666 21st St, San Francisco, California, 94114, (37.7564496899993, -122.42936434915458, 0.0))

# %%
import pandas
df=pandas.read_csv("supermarket.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df["Address"]=df["Address"]+", "+df["City"]+", "+df["State"]+", "+df["Country"]
df
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St, San Francisco, CA 94114, USA, Sa...  San Francisco
# 1   2  735 Dolores St, San Francisco, CA 94119, USA, ...  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, ...  San Francisco
# 3   4  3995 23rd St, San Francisco, CA 94114, USA, Sa...  San Francisco
# 4   5  1056 Sanchez St, San Francisco, California, US...  San Francisco
# 5   6  551 Alvarado St, San Francisco, CA 94114, USA,...  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Coordinates"]=df["Address"].apply(nom.geocode)
df.Coordinates[0].latitude
# Out:
# 37.7564496899993

# %%
df["Latitude"]=df["Coordinates"].apply(lambda x: x.latitude)
df["Longitude"]=df["Coordinates"].apply(lambda x: x.longitude)
df.set_index("ID")
df
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St, San Francisco, CA 94114, USA, Sa...  San Francisco
# 1   2  735 Dolores St, San Francisco, CA 94119, USA, ...  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, ...  San Francisco
# 3   4  3995 23rd St, San Francisco, CA 94114, USA, Sa...  San Francisco
# 4   5  1056 Sanchez St, San Francisco, California, US...  San Francisco
# 5   6  551 Alvarado St, San Francisco, CA 94114, USA,...  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# ...
